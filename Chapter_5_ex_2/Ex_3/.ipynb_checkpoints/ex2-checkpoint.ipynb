# %%
# using Distributed, SharedArrays
# # addprocs only run one time
# addprocs(12)

# %%
@everywhere include("code/acoustic_solver_parallel.jl");
@everywhere include("code/acoustic_solver.jl");
@everywhere include("code/adjoint_method_ot.jl")
@everywhere include("code/optimization.jl")

using PyPlot, JLD2
@everywhere using MAT, ImageFiltering

# %%
@everywhere begin
    Nx = 101
    Ny = 101
    c_true = 3*ones(Nx,Ny)
    for i = 1:Nx
        for j = 1:Ny
            if (i-51)^2+(j-51)^2 < 25^2
                c_true[i,j] = 3.6
            end
        end
    end
    c = 3*ones(Nx,Ny)
    rho = ones(Nx,Ny)
    h = 0.02

    # time
    Fs = 300;
    dt = 1/Fs;
    Nt = 500;
    t = range(0,length=Nt,step=dt);
    println("CFL: ", maximum(c_true) * dt / h);

    # source
    source = source_ricker(10,0.2,t)
    source_num = 11
    source_position = zeros(Int,source_num,2)
    for i = 1:source_num
            source_position[i,:] = [(i-1)*10+1,1]
    end
    source = repeat(source, 1, 1);

    # receiver
    receiver_num = 101
    receiver_position = zeros(Int,receiver_num,2)
    for i = 1:receiver_num
        receiver_position[i,:] = [(i-1)+1,101]
    end

    # PML
    pml_len = 50
    pml_coef = 50;
    
end
plot(t, source[:,1])
# Out:
# CFL: 0.6
#       From worker 3:	CFL: 0.6
#       From worker 2:	CFL: 0.6
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fc422aeb190>

# %%
figure
subplot(121); imshow(c, cmap="rainbow"); title("c"); colorbar(shrink=0.3); clim(3,3.5)
scatter(source_position[:,2].-1, source_position[:,1].-1)
scatter(receiver_position[:,2].-1, receiver_position[:,1].-1)

subplot(122); imshow(c_true, cmap="rainbow"); title("c true"); colorbar(shrink=0.3); clim(3,3.5)
scatter(source_position[:,2].-1, source_position[:,1].-1)
scatter(receiver_position[:,2].-1, receiver_position[:,1].-1)

tight_layout()
# Out:
# Figure(PyObject <Figure size 640x480 with 4 Axes>)

# %%
@time uu, received_data = multi_solver(c_true, rho, Nx, h, Ny, h, Nt, dt, source, source_position, receiver_position; pml_len=pml_len, pml_coef=pml_coef);
@time data = multi_solver_no_wavefield(c, rho, Nx, h, Ny, h, Nt, dt, source, source_position, receiver_position; pml_len=pml_len, pml_coef=pml_coef);
# Out:
#   9.772889 seconds (6.68 M allocations: 331.057 MiB, 1.21% gc time)
#   4.478939 seconds (394.75 k allocations: 20.369 MiB, 2.29% gc time)

# %%
subplot(121)
wv = uu[:,:,250,4]
imshow(wv, cmap="seismic"); clim(-1e-1,1e-1)

subplot(122)
imshow(received_data[:,:,4], cmap="gray", aspect=0.2); colorbar(shrink=0.3);
clim([-1e-1,1e-1]);
# Out:
# Figure(PyObject <Figure size 640x480 with 3 Axes>)

# %%
M = cost_matrix_1d(t,t)
reg = 1e-4
reg_m = 1e0
iterMax = 100
k = 10
# source ind
ind = 6

adj_l2 = data[:,:,ind] - received_data[:,:,ind];
dd, adj_ot = adj_source_ot_exp(data[:,:,ind], received_data[:,:,ind], M; reg=reg, reg_m=reg_m, iterMax=iterMax, k=k);

# %%
subplot(121)
imshow(adj_l2, cmap="gray", aspect=0.2); colorbar(shrink=0.3);
subplot(122)
imshow(adj_ot, cmap="gray", aspect=0.2); colorbar(shrink=0.3);
# Out:
# Figure(PyObject <Figure size 640x480 with 4 Axes>)

# %%
# min_value = minimum(c_true)
# max_value = maximum(c_true)
min_value = 0
max_value = 10
alpha = 1e-4
iterNum = 5
rho = 0.1
cc = 1e-10
maxSearchTime = 3
x0 = reshape(c, Nx*Ny, 1);

# %%
eval_fn(x) = obj_func_l2(received_data, x, rho, Nx, h, Ny, h, Nt, dt, source, source_position, receiver_position; pml_len=pml_len, pml_coef=pml_coef);

eval_grad(x) = grad_l2(received_data, x, rho, Nx, h, Ny, h, Nt, dt, source, source_position, receiver_position; pml_len=pml_len, pml_coef=pml_coef);

eval_fn_ot(x) = obj_func_ot(received_data, x, rho, Nx, h, Ny, h, Nt, dt, source, source_position, receiver_position, reg, reg_m, iterMax, k; pml_len=pml_len, pml_coef=pml_coef)

eval_grad_ot(x) = grad_ot(received_data, x, rho, Nx, h, Ny, h, Nt, dt, source, source_position, receiver_position, reg, reg_m, iterMax, k; pml_len=pml_len, pml_coef=pml_coef)
# Out:
# eval_grad_ot (generic function with 1 method)

# %%
@time dd, gg_ot = eval_grad_ot(c);
@time dd, gg_l2 = eval_grad(c);
# Out:
#  40.384642 seconds (3.32 M allocations: 176.761 MiB, 0.17% gc time)
#   8.098420 seconds (266.31 k allocations: 13.864 MiB, 1.09% gc time)

# %%
imshow(alpha*reshape(gg_ot,Nx,Ny), cmap="rainbow"); colorbar()
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x7fc40b00e0d0>

# %%
imshow(alpha*reshape(gg_l2,Nx,Ny), cmap="rainbow"); colorbar()
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x7fc40b6231c0>

# %%
# min_value = minimum(c_true)
# max_value = maximum(c_true)
min_value = 0
max_value = 10
alpha = 1e-4
iterNum = 5
cc = 1e-10
maxSearchTime = 3
x0 = copy(c)
x0 = reshape(x0, Nx*Ny, 1);

# xk, fn = nonlinear_cg(eval_fn, eval_grad, x0, alpha, iterNum, min_value, max_value; rho=rho, c=cc, maxSearchTime=maxSearchTime, threshold=1e-10);
xk_l2, fn = LBFGS(eval_fn, eval_grad, x0, alpha, iterNum, min_value, max_value; m=3, alpha_search=1, rho=0.1, c=1e-10, maxSearchTime=3, threshold=1e-10)
# Out:
# Main iteration: 1
# Start line search. fk: 1.28425e+02
#     alpha: 1.00000e-04    fk1: 9.14703e+01    fk-c*alpha*gradk^2: 1.28425e+02
# Line search succeed. Search time: 0.
# ----------------------------------------------------------------
# Start LBFGS.
# ----------------------------------------------------------------
# Main iteration: 2
# Start line search. fk: 9.14703e+01
#     alpha: 1.00000e+00    fk1: Inf    fk-c*alpha*gradk^2: 9.14703e+01
#     alpha: 1.00000e-01    fk1: 6.70381e+01    fk-c*alpha*gradk^2: 9.14703e+01
# Line search succeed. Search time: 1.
# ----------------------------------------------------------------
# Main iteration: 3
# Start line search. fk: 6.70381e+01
#     alpha: 1.00000e+00    fk1: NaN    fk-c*alpha*gradk^2: 6.70381e+01
#     alpha: 1.00000e-01    fk1: 3.16240e+01    fk-c*alpha*gradk^2: 6.70381e+01
# Line search succeed. Search time: 1.
# ----------------------------------------------------------------
# Main iteration: 4
# Start line search. fk: 3.16240e+01
#     alpha: 1.00000e+00    fk1: 1.20616e+93    fk-c*alpha*gradk^2: 3.16240e+01
#     alpha: 1.00000e-01    fk1: 3.09645e+01    fk-c*alpha*gradk^2: 3.16240e+01
# Line search succeed. Search time: 1.
# ----------------------------------------------------------------
# Main iteration: 5
# Start line search. fk: 3.09645e+01
#     alpha: 1.00000e+00    fk1: 1.04451e+247    fk-c*alpha*gradk^2: 3.09645e+01
#     alpha: 1.00000e-01    fk1: 2.90666e+01    fk-c*alpha*gradk^2: 3.09645e+01
# Line search succeed. Search time: 1.
# ----------------------------------------------------------------
# fk: 2.90666e+01 Iteration is done.
#
# ----------------------------------------------------------------
# ([3.816192375227434, 3.440416177868152, 3.28227766982292, 3.185745716675499, 3.0870912307821374, 2.959276845895729, 2.814528928313351, 2.7132614106016653, 2.773227308836204, 3.1208980828087696  …  3.136238356771622, 3.1487393418368503, 3.15869746550823, 3.1649351643497527, 3.1664589924077244, 3.1624484279932683, 3.1521104086273657, 3.1343071644650795, 3.106602935892973, 3.062376733526481], [128.42510212666392, 91.47029554098052, 67.03812132713892, 31.62395506142076, 30.964500424002463, 29.06663396279765])

# %%
imshow(reshape(xk_l2,Nx,Ny), cmap="rainbow"); colorbar(); clim(3,3.6)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
# min_value = minimum(c_true)
# max_value = maximum(c_true)
min_value = 0
max_value = 10
alpha = 5e-3
iterNum = 5
rho = 0.1
cc = 1e-10
maxSearchTime = 5
x0 = reshape(c, Nx*Ny, 1);

# xk, fn = nonlinear_cg(eval_fn_ot, eval_grad_ot, x0, alpha, iterNum, min_value, max_value; rho=rho, c=cc, maxSearchTime=maxSearchTime, threshold=1e-10);
xk_ot, fn = LBFGS(eval_fn_ot, eval_grad_ot, x0, alpha, iterNum, min_value, max_value; m=5, alpha_search=1, rho=0.1, c=1e-10, maxSearchTime=5, threshold=1e-10)
# Out:
# Main iteration: 1
# Start line search. fk: 3.31948e+02
#     alpha: 5.00000e-03    fk1: 2.77666e+02    fk-c*alpha*gradk^2: 3.31948e+02
# Line search succeed. Search time: 0.
# ----------------------------------------------------------------
# Start LBFGS.
# ----------------------------------------------------------------
# Main iteration: 2
# Start line search. fk: 2.77666e+02
#     alpha: 1.00000e+00    fk1: 1.91858e+02    fk-c*alpha*gradk^2: 2.77666e+02
# Line search succeed. Search time: 0.
# ----------------------------------------------------------------
# Main iteration: 3
# Start line search. fk: 1.91858e+02
#     alpha: 1.00000e+00    fk1: 1.62716e+02    fk-c*alpha*gradk^2: 1.91858e+02
# Line search succeed. Search time: 0.
# ----------------------------------------------------------------
# Main iteration: 4
# Start line search. fk: 1.62716e+02
#     alpha: 1.00000e+00    fk1: 1.61495e+02    fk-c*alpha*gradk^2: 1.62716e+02
# Line search succeed. Search time: 0.
# ----------------------------------------------------------------
# Main iteration: 5
# Start line search. fk: 1.61495e+02
#     alpha: 1.00000e+00    fk1: 1.61901e+02    fk-c*alpha*gradk^2: 1.61495e+02
#     alpha: 1.00000e-01    fk1: 1.61396e+02    fk-c*alpha*gradk^2: 1.61495e+02
# Line search succeed. Search time: 1.
# ----------------------------------------------------------------
# fk: 1.61396e+02 Iteration is done.
#
# ----------------------------------------------------------------
# ([3.261021263566474, 3.1947722917441324, 3.1576496715026168, 3.1273681420476347, 3.0836710727522636, 3.0191964212726345, 2.958198673799972, 2.957101952984713, 3.041829949896369, 3.1415036338981897  …  3.1232243747399595, 3.121408022659924, 3.1196845819817245, 3.118095523536356, 3.11635791431873, 3.114046246959077, 3.1104909969025396, 3.1043703145136026, 3.0929659651794417, 3.0700231941020464], [331.9482250788009, 277.66599508843296, 191.85811549193755, 162.71604820220264, 161.49479578067098, 161.39551267977194])

# %%
imshow(reshape(xk_ot,Nx,Ny), cmap="rainbow"); colorbar(); clim(3,3.6)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
# @save "result_ex3.jld2" xk_l2 xk_ot c c_true Nx Ny h t reg reg_m iterMax k adj_l2 adj_ot
